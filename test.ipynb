# %%
from langchain_cohere import ChatCohere
def maze_ai(query):
    llm = ChatCohere(
        model="command-r-08-2024",
        temperature=0,
        cohere_api_key="S7NonwWcXFTLqxiHwqbtpT7HcZchJ0MA87W90XYS",
        max_tokens=10,
        )
    return llm.invoke(query).content

# %%
# Out:
# 'Artificial Intelligence (AI) is a field of computer science and a branch of engineering that focuses on creating intelligent machines and systems capable of performing tasks and making decisions typically associated with human intelligence. It involves developing algorithms, models, and technologies to enable computers and machines to perceive, reason, learn, and act in a manner that mimics or enhances human cognitive abilities.\n\nAI encompasses a wide range of techniques and applications, including machine learning, natural language processing, computer vision, expert systems, robotics, and more. The ultimate goal of AI is to design and develop systems that can solve complex problems, adapt to new situations, and exhibit intelligent behavior, often by processing large amounts of data and using advanced algorithms to make informed decisions.\n\nSome key characteristics and capabilities of AI include:\n\n1. Learning: AI systems can learn from data, either through supervised learning (using labeled examples), unsupervised learning (identifying patterns in unlabeled data), or reinforcement learning (learning through trial and error).\n\n2. Problem Solving: AI enables machines to solve complex problems by breaking them down into smaller, more manageable tasks and applying logical reasoning and decision-making processes.\n\n3. Pattern Recognition: AI algorithms can identify patterns, trends, and relationships in data, which is useful for tasks like image and speech recognition, fraud detection, and predictive analytics.\n\n4. Natural Language Understanding: AI-powered systems can understand and interpret human language, allowing for interactions through voice assistants, chatbots, and language translation services.\n\n5. Automation: AI is often used to automate repetitive and time-consuming tasks, improving efficiency and reducing human error.\n\n6. Decision Support: AI provides valuable insights and recommendations to support human decision-making in various domains, such as healthcare, finance, and business.\n\n7. Adaptability: Advanced AI systems can adapt and improve over time, learning from new data and experiences to enhance their performance.\n\nArtificial Intelligence has a wide range of applications across industries, including healthcare, finance, transportation, entertainment, and many others, revolutionizing the way we live, work, and interact with technology.'
